# %% [markdown]
# <a href="https://colab.research.google.com/github/femartinsamorim/tera_datascience_e_machinelearning/blob/main/Introdu%C3%A7%C3%A3o_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('list.csv')

# %%
df.head()
# Out:
#    idades  alturas  Unnamed: 2  Unnamed: 3 Unnamed: 4
# 0    10.0    165.0         NaN         NaN        NaN
# 1    25.0    180.0         NaN         NaN        NaN
# 2    24.0    176.0         NaN         NaN        NaN
# 3    42.0    184.0         NaN         NaN        NaN
# 4     NaN      NaN         NaN         NaN        NaN

# %%
df.describe()
# Out:
#           idades     alturas  Unnamed: 2  Unnamed: 3
# count   4.000000    4.000000         0.0         0.0
# mean   25.250000  176.250000         NaN         NaN
# std    13.098982    8.180261         NaN         NaN
# min    10.000000  165.000000         NaN         NaN
# 25%    20.500000  173.250000         NaN         NaN
# 50%    24.500000  178.000000         NaN         NaN
# 75%    29.250000  181.000000         NaN         NaN
# max    42.000000  184.000000         NaN         NaN

# %%
df.tail(1)
# Out:
#     idades  alturas  Unnamed: 2  Unnamed: 3 Unnamed: 4
# 21     NaN      NaN         NaN         NaN        -6-

# %%
dados = {'Artistas':['Korn','Slipknot','S.O.A.D','Linkin Park'], \
         'Disco':['Issues','Iowa','Toxicity','Hybrid Theory'],'Lançamento':[1999, 2001, 2001, 2000 ]}

df2 = pd.DataFrame(dados)
print(df2)
# Out:
#       Artistas          Disco  Lançamento
# 0         Korn         Issues        1999
# 1     Slipknot           Iowa        2001
# 2      S.O.A.D       Toxicity        2001
# 3  Linkin Park  Hybrid Theory        2000

# %%
media = int(df2.mean())
print(f'média dos lançamentos: {media}')
# Out:
# média dos lançamentos: 2000
# <ipython-input-31-452fefe995b3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   media = int(df2.mean())

# %%
print(df2)
# Out:
#       Artistas          Disco  Lançamento
# 0         Korn         Issues        1999
# 1     Slipknot           Iowa        2001
# 2      S.O.A.D       Toxicity        2001
# 3  Linkin Park  Hybrid Theory        2000

# %%
df2['Artistas'] != ''
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: Artistas, dtype: bool

# %%
df2[df2['Artistas'] != '']
# Out:
#       Artistas          Disco  Lançamento
# 0         Korn         Issues        1999
# 1     Slipknot           Iowa        2001
# 2      S.O.A.D       Toxicity        2001
# 3  Linkin Park  Hybrid Theory        2000

# %%
df2['Lançamento'] > 2000
df2[df2['Lançamento'] > 2000]
# Out:
#    Artistas     Disco  Lançamento
# 1  Slipknot      Iowa        2001
# 2   S.O.A.D  Toxicity        2001

# %%
df2.hist(bins = 5)
# Out:
# array([[<Axes: title={'center': 'Lançamento'}>]], dtype=object)
